# %% [markdown]
# # Rich Output

# %% [markdown]
# In Python, objects can declare their textual representation using the `__repr__` method.

# %%
class Ball(object):
    pass

b = Ball()
b.__repr__()
# Out:
# '<__main__.Ball object at 0x10527cad0>'

# %%
print(b)
# Out:
# <__main__.Ball object at 0x10527cad0>

# %% [markdown]
# Overriding the `__repr__` method:

# %%
class Ball(object):
    def __repr__(self):
        return 'TEST'

b = Ball()

# %%
print(b)
# Out:
# TEST

# %% [markdown]
# IPython expands on this idea and allows objects to declare other, rich representations including:
#
# * HTML
# * JSON
# * PNG
# * JPEG
# * SVG
# * LaTeX
#
# A single object can declare **some or all** of these representations; all of them are handled by IPython's *display system*. .

# %% [markdown]
# ## Basic display imports

# %% [markdown]
# The `display` function is a general purpose tool for displaying different representations of objects. Think of it as `print` for these rich representations.

# %%
from IPython.display import display

# %% [markdown]
# A few points:
#
# * Calling `display` on an object will send **all** possible representations to the Notebook.
# * These representations are stored in the Notebook document.
# * In general the Notebook will use the richest available representation.
#
# If you want to display a particular representation, there are specific functions for that:

# %%
from IPython.display import (
    display_pretty, display_html, display_jpeg,
    display_png, display_json, display_latex, display_svg
)

# %% [markdown]
# ## Images

# %% [markdown]
# To work with images (JPEG, PNG) use the `Image` class.

# %%
from IPython.display import Image

# %%
i = Image(filename='../images/ipython-image.png')
display(i)

# %% [markdown]
# Returning an `Image` object from an expression will automatically display it:

# %%
i

# %% [markdown]
# An image can also be displayed from raw data or a URL.

# %%
Image(url='http://python.org/images/python-logo.gif')
# Out:
# <img src="http://python.org/images/python-logo.gif"/>

# %% [markdown]
# SVG images are also supported out of the box.

# %%
from IPython.display import SVG
SVG(filename='../images/python.svg')

# %% [markdown]
# ## HTML

# %% [markdown]
# Python objects can declare HTML representations that will be displayed in the Notebook. If you have some HTML you want to display, simply use the `HTML` class.

# %%
from IPython.display import HTML

# %%
s = """<table>
<tr>
<th>Header 1</th>
<th>Header 2</th>
</tr>
<tr>
<td>row 1, cell 1</td>
<td>row 1, cell 2</td>
</tr>
<tr>
<td>row 2, cell 1</td>
<td>row 2, cell 2</td>
</tr>
</table>"""

# %%
h = HTML(s)

# %%
display(h)
# Out:
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>

# %% [markdown]
# You can also use the `%%html` cell magic to accomplish the same thing.

# %%
# %%html
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>
# Out:
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>

# %%
# %%html
# <style>
# #notebook {
#     background-color: skyblue;
#     font-family: times new roman;
# }
# </style>

# %% [markdown]
# You can remove the abvove styling by using "Cell"$\rightarrow$"Current Output"$\rightarrow$"Clear" with that cell selected.

# %% [markdown]
# ## JavaScript

# %% [markdown]
# The Notebook also enables objects to declare a JavaScript representation. At first, this may seem odd as  output is inherently visual and JavaScript is a programming language. However, this opens the door for rich output that leverages the full power of JavaScript and associated libraries such as [d3.js](http://d3js.org) for output.

# %%
from IPython.display import Javascript

# %% [markdown]
# Pass a string of JavaScript source code to the `JavaScript` object and then display it.

# %%
js = Javascript('alert("hi")');

# %%
display(js)

# %% [markdown]
# The same thing can be accomplished using the `%%javascript` cell magic:

# %%
# %%javascript
#
# alert("hi");

# %% [markdown]
# Here is a more complicated example that loads `d3.js` from a CDN, uses the `%%html` magic to load CSS styles onto the page and then runs ones of the `d3.js` examples.

# %%
Javascript(
    """$.getScript('//cdnjs.cloudflare.com/ajax/libs/d3/3.2.2/d3.v3.min.js')"""
)

# %%
# %%html
# <style type="text/css">
#
# circle {
#   fill: rgb(31, 119, 180);
#   fill-opacity: .25;
#   stroke: rgb(31, 119, 180);
#   stroke-width: 1px;
# }
#
# .leaf circle {
#   fill: #ff7f0e;
#   fill-opacity: 1;
# }
#
# text {
#   font: 10px sans-serif;
# }
#
# </style>
# Out:
# <style type="text/css">
#
# circle {
#   fill: rgb(31, 119, 180);
#   fill-opacity: .25;
#   stroke: rgb(31, 119, 180);
#   stroke-width: 1px;
# }
#
# .leaf circle {
#   fill: #ff7f0e;
#   fill-opacity: 1;
# }
#
# text {
#   font: 10px sans-serif;
# }
#
# </style>

# %%
# %%javascript
#
# // element is the jQuery element we will append to
# var e = element.get(0);
#
# var diameter = 600,
#     format = d3.format(",d");
#
# var pack = d3.layout.pack()
#     .size([diameter - 4, diameter - 4])
#     .value(function(d) { return d.size; });
#
# var svg = d3.select(e).append("svg")
#     .attr("width", diameter)
#     .attr("height", diameter)
#   .append("g")
#     .attr("transform", "translate(2,2)");
#
# d3.json("data/flare.json", function(error, root) {
#   var node = svg.datum(root).selectAll(".node")
#       .data(pack.nodes)
#     .enter().append("g")
#       .attr("class", function(d) { return d.children ? "node" : "leaf node"; })
#       .attr("transform", function(d) { return "translate(" + d.x + "," + d.y + ")"; });
#
#   node.append("title")
#       .text(function(d) { return d.name + (d.children ? "" : ": " + format(d.size)); });
#
#   node.append("circle")
#       .attr("r", function(d) { return d.r; });
#
#   node.filter(function(d) { return !d.children; }).append("text")
#       .attr("dy", ".3em")
#       .style("text-anchor", "middle")
#       .text(function(d) { return d.name.substring(0, d.r / 3); });
# });
#
# d3.select(self.frameElement).style("height", diameter + "px");

# %% [markdown]
# ## Audio

# %% [markdown]
# IPython makes it easy to work with sounds interactively. The `Audio` display class allows you to create an audio control that is embedded in the Notebook. The interface is analogous to the interface of the `Image` display class. All audio formats supported by the browser can be used. Note that no single format is presently supported in all browsers.

# %%
from IPython.display import Audio
Audio(url="http://www.nch.com.au/acm/8k16bitpcm.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="http://www.nch.com.au/acm/8k16bitpcm.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# A NumPy array can be converted to audio. The `Audio` class normalizes and encodes the data and embeds the resulting audio in the Notebook.
#
# For instance, when two sine waves with almost the same frequency are superimposed a phenomena known as [beats](https://en.wikipedia.org/wiki/Beat_%28acoustics%29) occur:

# %%
import numpy as np
max_time = 3
f1 = 220.0
f2 = 224.0
rate = 8000.0
L = 3
times = np.linspace(0,L,rate*L)
signal = np.sin(2*np.pi*f1*times) + np.sin(2*np.pi*f2*times)

Audio(data=signal, rate=rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Video

# %% [markdown]
# More exotic objects can also be displayed, as long as their representation supports the IPython display protocol.  For example, videos hosted externally on YouTube are easy to load:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('sjfsUzECqK0')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/sjfsUzECqK0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## External sites

# %% [markdown]
# You can even embed an entire page from another site in an iframe; for example this is IPython's home page:

# %%
from IPython.display import IFrame
IFrame('http://ipython.org', width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="http://ipython.org"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Links to local files

# %% [markdown]
# IPython provides builtin display classes for generating links to local files. Create a link to a single file using the `FileLink` object:

# %%
from IPython.display import FileLink, FileLinks
FileLink('../Viz/Vis1.ipynb')
# Out:
# /Users/bgranger/github/datascience4e/ds4e/Content/Viz/Vis1.ipynb

# %% [markdown]
# Alternatively, to generate links to all of the files in a directory, use the `FileLinks` object, passing `'.'` to indicate that we want links generated for the current working directory. Note that if there were other directories under the current directory, `FileLinks` would work in a recursive manner creating links to files in all sub-directories as well.

# %%
FileLinks('../')
# Out:
# ../
#   .DS_Store
# ../Data/
#   Data1.ipynb
#   Data1Exercises.ipynb
# ../Data/.ipynb_checkpoints/
#   Data1-checkpoint.ipynb
#   Data1Exercises-checkpoint.ipynb
# ../Notebook/
#   Custom Display Logic.ipynb
#   Rich Output Exercises.ipynb
#   Rich Output.ipynb
# ../Notebook/.ipynb_checkpoints/
#   Rich Output-checkpoint.ipynb
# ../Numpy/
#   Numpy Exercises.ipynb
#   Numpy.ipynb
#   vizarray.py
#   vizarray.pyc
# ../Numpy/.ipynb_checkpoints/
#   Numpy Exercises-checkpoint.ipynb
#   NumPy-checkpoint.ipynb
# ../Packages/
#   Python Packages Exercises.ipynb
#   Python Packages.ipynb
# ../Packages/.ipynb_checkpoints/
#   Python Packages-checkpoint.ipynb
# ../Pandas/
#   .DS_Store
#   Chapter5Exercises.ipynb
# ../Pandas/.ipynb_checkpoints/
#   Basic Pandas-checkpoint.ipynb
#   Chapter5Exercises-checkpoint.ipynb
#   DataSources-checkpoint.ipynb
#   MovieLens-checkpoint.ipynb
#   USADotGov-checkpoint.ipynb
#   USBabyNames-checkpoint.ipynb
# ../Python/
#   Basic Python Syntax Exercises.ipynb
#   Basic Python Syntax.ipynb
# ../Python/.ipynb_checkpoints/
#   Basic Python Syntax Exercises-checkpoint.ipynb
#   Basic Python Syntax-checkpoint.ipynb
# ../Scipy/
#   Scipy Exercises.ipynb
#   Scipy.ipynb
# ../Scipy/.ipynb_checkpoints/
#   Scipy Exercises-checkpoint.ipynb
#   SciPy-checkpoint.ipynb
# ../Scratch/
#   .DS_Store
#   Basic Pandas.ipynb
#   DataSources.ipynb
#   ml-1m.zip
#   MovieLens.ipynb
#   names.zip
#   Pandas.ipynb
#   ProbPandas.ipynb
#   USADotGov.ipynb
#   usagov_bitly_data2013-05-17-1368832207
#   USBabyNames.ipynb
# ../Scratch/ml-1m/
#   movies.dat
#   ratings.dat
#   README
#   users.dat
# ../Scratch/names/
#   NationalReadMe.pdf
#   yob1880.txt
#   yob1881.txt
#   yob1882.txt
#   yob1883.txt
#   yob1884.txt
#   yob1885.txt
#   yob1886.txt
#   yob1887.txt
#   yob1888.txt
#   yob1889.txt
#   yob1890.txt
#   yob1891.txt
#   yob1892.txt
#   yob1893.txt
#   yob1894.txt
#   yob1895.txt
#   yob1896.txt
#   yob1897.txt
