# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('class_survey.csv', names=['timestamp','salary','age','sport','zip','gender','marital','degree',
                                              'credit_cards','sleep_time','wake_time','trips_per_year',
                                              'mobile_os','desktop_os','sms_per_day','email_service',
                                              'emails_per_day','online_shopping'],
                 header=0, index_col=False)

# %%
df.head()
# Out:
#              timestamp       salary    age      sport    zip  gender marital  \
# 0  10/14/2014 14:21:54      $0-$50k  20-30    Cricket  95050    Male  Single
# 1  10/14/2014 14:26:51      $0-$50k  20-30   Swimming  95050  Female  Single
# 2  10/14/2014 14:32:20  $100k-$150k  20-30     Tennis  95117    Male  Single
# 3  10/14/2014 14:47:20    $50k-100k  20-30     Rowing  95126    Male  Single
# 4  10/14/2014 15:04:31      $0-$50k  20-30  BADMINTON  95050  Female  Single
#
#       degree  credit_cards   sleep_time    wake_time  trips_per_year  \
# 0  Bachelors             4   1:00:00 AM   6:00:00 AM               0
# 1    Masters             0   2:00:00 AM  11:00:00 AM               1
# 2    Masters            12   1:30:00 AM   8:00:00 AM               2
# 3  Bachelors             4  10:30:00 PM   6:30:00 AM               5
# 4  Bachelors             0  12:30:00 PM   9:30:00 AM               1
#
#   mobile_os desktop_os  sms_per_day email_service  emails_per_day  \
# 0       iOS    Windows           20         GMAIL              10
# 1       iOS    Windows            9         yahoo               5
# 2   Android    Windows           50         Gmail              30
# 3       iOS    Windows           10         gmail               8
# 4   Android        Mac           20         GMAIL              10
#
#    online_shopping
# 0               40
# 1                0
# 2               96
# 3               25
# 4               50

# %%
df.describe()
# Out:
#                 zip  credit_cards  trips_per_year  sms_per_day  \
# count     42.000000     40.000000       40.000000     40.00000
# mean   94973.809524      2.375000        2.150000     28.50000
# std      275.456892      2.498076        2.166765     80.62544
# min    94086.000000      0.000000        0.000000      0.00000
# 25%    95050.000000      1.000000        1.000000      2.75000
# 50%    95050.000000      1.500000        1.500000     10.00000
# 75%    95096.000000      3.000000        3.000000     20.00000
# max    95134.000000     12.000000       12.000000    500.00000
#
#        emails_per_day  online_shopping
# count       41.000000        41.000000
# mean        10.536585        38.317073
# std          9.889635        23.661613
# min          2.000000         0.000000
# 25%          5.000000        20.000000
# 50%          8.000000        40.000000
# 75%         10.000000        50.000000
# max         50.000000        96.000000
